# %% [markdown]
# #### T2 - 명사만 추출된 title df에서 빈도분석 실시
#
# #### outputs :

# %%
import pandas as pd
import os

# %%
df_noun_title = pd.read_csv('../outputs/T1_out1_df_noun_title.csv',encoding='utf-8')
os.chdir(path='../outputs/') # 저장경로 설정

# %%
res1_freq_noun =df_noun_title.groupby('token').count().sort_values(by='art_id',ascending=False)

res1_freq_noun.head(50)
# Out:
#        art_id  type
# token
# 개발자       773   773
# 신입        609   609
# 가요        580   580
# 질문        396   396
# 엔드        367   367
# vs        351   351
# 조언        348   348
# 국비        347   347
# 회사        335   335
# 관련        316   316
# 프로젝트      293   293
# 고민        290   290
# 개발        290   290
# 프론트엔드     283   283
# si        257   257
# 비전공자      241   241
# 국비지원      235   235
# 공부        222   222
# 취업        220   220
# 전공        204   204
# 정도        194   194
# 프리랜서      193   193
# 국비학원      182   182
# 자바        178   178
# 연봉        170   170
# 노트북       164   164
# 요즘        157   157
# 추천        149   149
# 면접        146   146
# 커리큘럼      144   144
# 학원        143   143
# 보통        140   140
# 기업        121   121
# 포트폴리오     121   121
# 학년        120   120
# 프리        117   117
# 컴공        116   116
# 부트캠프      115   115
# 취준        113   113
# 경력        112   112
# it        111   111
# 진로        110   110
# 퇴사        106   106
# 코딩테스트      92    92
# ...
